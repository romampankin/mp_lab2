# %%
import matplotlib.pyplot as plt
# bin_tree_time = {100: 9.650399999999726e-05, 1000: 4.056599999996413e-05, 2000: 3.9379999999977766e-05, 3000: 3.675300000000048e-05, 10000: 4.695999999992928e-05, 30000: 3.8312000000040314e-05, 70000: 3.829899999985287e-05}
# rb_tree_time = {100: 2.8478999999997923e-05, 1000: 1.988799999996793e-05, 2000: 1.5039999999966192e-05, 3000: 1.1884999999989265e-05, 10000: 2.941299999992264e-05, 30000: 1.4348000000108385e-05, 70000: 1.5116000000148233e-05}
# hash_table_time = {100: 3.7237999999995e-05, 1000: 2.4636999999994025e-05, 2000: 1.438700000000459e-05, 3000: 1.4025000000028598e-05, 10000: 6.80509999999579e-05, 30000: 1.5435000000119103e-05, 70000: 1.6265000001070007e-05}
# dictionary_time = {100: 8.637000000005779e-06, 1000: 6.614999999987603e-06, 2000: 3.79200000000246e-05, 3000: 6.032000000044668e-06, 10000: 9.227000000056051e-06, 30000: 3.5052999999951595e-05, 70000: 9.126000000136969e-06}
collision_number = {1000: 115, 2000: 116, 3000: 116, 10000: 116, 30000: 116, 70000: 116}

bin_tree_time= {0:0,  2000: 3.325499999998205e-05, 3000: 3.308499999998826e-05, 10000: 6.03119999999613e-05, 30000: 3.1638999999916706e-05, 70000: 4.0202999999294775e-05}
rb_tree_time= {0:0,  2000: 1.3354999999992678e-05, 3000: 1.1834000000043865e-05, 10000: 5.4896999999988196e-05, 30000: 1.3072999999863555e-05, 70000: 2.4152000000322573e-05}
hash_table_time= {0:0,  2000: 1.5114000000010508e-05, 3000: 1.4942999999989492e-05, 10000: 2.0951999999963e-05, 30000: 1.677099999985998e-05, 70000: 2.8053999999599e-05}
dictionary_time= {0:0,  2000: 8.753000000000233e-06, 3000: 8.994999999956121e-06, 10000: 1.74279999999305e-05, 30000: 9.601999999997446e-06, 70000: 9.582999999385197e-06}
dicts = [bin_tree_time, rb_tree_time, hash_table_time, dictionary_time, collision_number]
dict_names = ['Binary Tree', 'Red-Black Tree', 'Hash Table', 'Dictionary', 'Collision Number']
colors = ['b', 'g', 'r', 'c', 'm', 'i', 'k', 'p']
# for idx, d in enumerate(dicts):
#     plt.figure(idx)
#     plt.title(dict_names[idx])
#     plt.xlabel('Размер выборки')
#     plt.ylabel('Время(сек.)')
#     # Добавьте цвет на график
#     plt.plot(list(d.keys()), list(d.values()), color=colors[idx])
#     plt.show()

plt.xlabel('Размер выборки')
plt.ylabel('Время(сек.)')
plt.plot(list(bin_tree_time.keys()), list(bin_tree_time.values()), list(rb_tree_time.keys()), list(rb_tree_time.values()), list(hash_table_time.keys()), list(hash_table_time.values()), list(dictionary_time.keys()), list(dictionary_time.values()))
plt.legend(['Binary', 'Red black', 'Hash table', 'Dictionary'])

print(f'\nbin_tree_time: {bin_tree_time}', f'rb_tree_time: {rb_tree_time}', f'hash_table_time: {hash_table_time}', f'dictionary_time: {dictionary_time}', f'collision_number{collision_number}', sep='\n')
# Out:
# bin_tree_time: {0: 0, 2000: 3.325499999998205e-05, 3000: 3.308499999998826e-05, 10000: 6.03119999999613e-05, 30000: 3.1638999999916706e-05, 70000: 4.0202999999294775e-05}
# rb_tree_time: {0: 0, 2000: 1.3354999999992678e-05, 3000: 1.1834000000043865e-05, 10000: 5.4896999999988195e-05, 30000: 1.3072999999863555e-05, 70000: 2.4152000000322572e-05}
# hash_table_time: {0: 0, 2000: 1.5114000000010508e-05, 3000: 1.4942999999989492e-05, 10000: 2.0951999999963e-05, 30000: 1.677099999985998e-05, 70000: 2.8053999999599e-05}
# dictionary_time: {0: 0, 2000: 8.753000000000233e-06, 3000: 8.994999999956121e-06, 10000: 1.74279999999305e-05, 30000: 9.601999999997446e-06, 70000: 9.582999999385198e-06}
# collision_number{1000: 115, 2000: 116, 3000: 116, 10000: 116, 30000: 116, 70000: 116}
